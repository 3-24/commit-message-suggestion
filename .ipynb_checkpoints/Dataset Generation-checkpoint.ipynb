# %%
# mount drive https://datascience.stackexchange.com/questions/29480/uploading-images-folder-from-my-system-into-google-colab
# login with your google account and type authorization code to mount on your googlbie drive.
from google.colab import drive
drive.mount('/gdrive')
root = '/gdrive/My Drive/CS492I/project'
# Out:
# Mounted at /gdrive

# %%
root = '.'

# %% [markdown]
# ## 1. Collect CodeSearchNet Repositories

# %%
import json

import pandas as pd
from pathlib import Path
pd.set_option('max_colwidth',300)
from pprint import pprint

# %%
# !wget https://s3.amazonaws.com/code-search-net/CodeSearchNet/v2/python.zip
# !mkdir CodeSearchNet
# !unzip python.zip -d CodeSearchNet
# Out:
# --2021-12-03 07:32:59--  https://s3.amazonaws.com/code-search-net/CodeSearchNet/v2/python.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.69.238
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.69.238|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 940909997 (897M) [application/zip]
# Saving to: ‘python.zip’
#
# python.zip          100%[===================>] 897.32M  65.4MB/s    in 13s
#
# 2021-12-03 07:33:12 (68.1 MB/s) - ‘python.zip’ saved [940909997/940909997]
#
# Archive:  python.zip
#    creating: CodeSearchNet/python/
#    creating: CodeSearchNet/python/final/
#    creating: CodeSearchNet/python/final/jsonl/
#    creating: CodeSearchNet/python/final/jsonl/train/
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_9.jsonl.gz
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_12.jsonl.gz
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_10.jsonl.gz
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_0.jsonl.gz
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_6.jsonl.gz
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_2.jsonl.gz
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_4.jsonl.gz
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_8.jsonl.gz
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_11.jsonl.gz
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_5.jsonl.gz
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_13.jsonl.gz
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_3.jsonl.gz
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_1.jsonl.gz
#   inflating: CodeSearchNet/python/final/jsonl/train/python_train_7.jsonl.gz
#    creating: CodeSearchNet/python/final/jsonl/test/
#   inflating: CodeSearchNet/python/final/jsonl/test/python_test_0.jsonl.gz
#    creating: CodeSearchNet/python/final/jsonl/valid/
#   inflating: CodeSearchNet/python/final/jsonl/valid/python_valid_0.jsonl.gz
#   inflating: CodeSearchNet/python_dedupe_definitions_v2.pkl
#   inflating: CodeSearchNet/python_licenses.pkl

# %%
python_files = sorted(Path('CodeSearchNet/python').glob('**/*.gz'))
print(python_files)
# Out:
# [PosixPath('CodeSearchNet/python/final/jsonl/test/python_test_0.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_0.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_1.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_10.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_11.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_12.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_13.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_2.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_3.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_4.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_5.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_6.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_7.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_8.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/train/python_train_9.jsonl.gz'), PosixPath('CodeSearchNet/python/final/jsonl/valid/python_valid_0.jsonl.gz')]

# %%
columns_long_list = ['repo', 'path', 'url', 'code', 
                     'code_tokens', 'docstring', 'docstring_tokens', 
                     'language', 'partition']

def jsonl_list_to_dataframe(file_list, columns=columns_long_list):
    """Load a list of jsonl.gz files into a pandas DataFrame."""
    return pd.concat([pd.read_json(f, 
                                   orient='records', 
                                   compression='gzip',
                                   lines=True)[columns] 
                      for f in file_list], sort=False)

# %%
pydf = jsonl_list_to_dataframe(python_files, columns=['repo'])
pydf = pydf.drop_duplicates().reset_index(drop=True)
pydf.to_pickle(f"{root}/repos.pkl")

# %% [markdown]
# ## 2. Collect diff and commits

# %%
# !pip install pydriller
# !pip install pandas
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydriller in /home/minus21/.local/lib/python3.9/site-packages (2.0)
# Requirement already satisfied: pytz in /home/minus21/.local/lib/python3.9/site-packages (from pydriller) (2021.1)
# Requirement already satisfied: gitpython in /home/minus21/.local/lib/python3.9/site-packages (from pydriller) (3.1.24)
# Requirement already satisfied: lizard in /home/minus21/.local/lib/python3.9/site-packages (from pydriller) (1.17.9)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/minus21/.local/lib/python3.9/site-packages (from gitpython->pydriller) (4.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/minus21/.local/lib/python3.9/site-packages (from gitpython->pydriller) (3.10.0.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/minus21/.local/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython->pydriller) (5.0.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/minus21/.local/lib/python3.9/site-packages (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/minus21/.local/lib/python3.9/site-packages (from pandas) (1.21.2)
# Requirement already satisfied: pytz>=2017.3 in /home/minus21/.local/lib/python3.9/site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/minus21/.local/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/minus21/.local/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/minus21/.local/lib/python3.9/site-packages (3.6.5)
# Requirement already satisfied: click in /home/minus21/.local/lib/python3.9/site-packages (from nltk) (8.0.1)
# Requirement already satisfied: tqdm in /home/minus21/.local/lib/python3.9/site-packages (from nltk) (4.62.1)
# Requirement already satisfied: joblib in /home/minus21/.local/lib/python3.9/site-packages (from nltk) (1.0.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/minus21/.local/lib/python3.9/site-packages (from nltk) (2021.11.10)

# %%
from pydriller import *
import pandas as pd
from nltk.tokenize import regexp_tokenize
import re
from itertools import chain
import json

# %%
repodf = pd.read_pickle(f"{root}/repos.pkl")
print(repodf.shape)
print(repodf)
# Out:
# (13590, 1)
#                                  repo
# 0                     soimort/you-get
# 1                      apache/airflow
# 2                      pytorch/vision
# 3                      asciimoo/searx
# 4              tensorflow/probability
# ...                               ...
# 13585         praekelt/python-ambient
# 13586                 zenreach/py-era
# 13587  TakesxiSximada/custom_settings
# 13588            openpermissions/bass
# 13589               xnuinside/clifier
#
# [13590 rows x 1 columns]

# %%
repodf.index[repodf['repo'] == "lepture/python-livereload"].tolist()
# Out:
# [8210]

# %%
def basic_filter(message):
    return message.split("\n", 1)[0].strip()

# Remove [label] in front of commit if exists
def label_filter(message):
    if (message.startswith('[')):
        end_bracket_index = message.find(']')
        if (end_bracket_index == -1):
            return None
        return message[end_bracket_index+1:]
    return message

def camel_case_split(str):
    return re.findall(r'[A-Z](?:[a-z]+|[A-Z]*(?=[A-Z]|$))', str)

def case_splitter(token):
    return list(map(lambda x: x.lower(), camel_case_split(token[0].upper() + token[1:]) if token[0].isalpha() else [token]))


def split_by_quote(diff):
    text_list = [(0,0)]
    quote_state = 0 #["out","single","double","Single","Double","quote"]
    i=0
    while i<len(diff):
      if diff[i] == "\\":i+=1
      elif (diff[i] == "\n" and quote_state == 5) or (diff[i] == '#' and quote_state == 0):
        text_list.append((quote_state,i))
        quote_state = abs(5-quote_state)
      elif diff[i] == '"':
        if i+2<len(diff) and diff[i:i+3]=='"""' and (quote_state == 0 or quote_state ==4):
          text_list.append((quote_state,i+max(quote_state-1,0)))
          quote_state = abs(4-quote_state)
          i+=2
        elif quote_state == 0 or quote_state == 2:
          text_list.append((quote_state,i+max(quote_state-1,0)))
          quote_state = abs(2-quote_state)
      elif diff[i] == "'":
        if i+2<len(diff) and diff[i:i+3] == "'''" and (quote_state == 0 or quote_state == 3):
          text_list.append((quote_state,i+quote_state))
          quote_state = abs(3-quote_state)
          i+=2
        elif quote_state == 0 or quote_state == 1:
          text_list.append((quote_state,i+quote_state))
          quote_state = abs(1-quote_state)
      i+=1
    text_list.append((quote_state,i))
    return [(text_list[i][0]==0,diff[text_list[i-1][1]:text_list[i][1]]) for i in range(1,len(text_list))]
  

token_regex = r"""(?x)
<(?:add|del)>   #Filtered eariler
|(?:[-+*/^&~|=%!<>@?$][\s]*)+     #Sequence of symbols
|[\n]                    #Change row
|[a-zA-Z]+               #General text
|[0-9]+                  #Number
"""
string_regex = r"""(?x)
<(?:add|del)>
|[\n]
|[a-zA-Z]+
"""
def diff_tokenizer(diff_text):
    diff = '\n'.join(map(lambda x: x[1], filter(lambda y: y[0] % 2 == 0, enumerate(diff_text.split("@@")))))
    diff = diff.replace('\n+', '\n<add>').replace('\n-', '\n<del>')
    diff = re.sub(r"(?:\n[ \t\r\f\v]*)+","\n",diff) # Join continuous row change
    quote_split = split_by_quote(diff)
    token_initial = chain.from_iterable(map(lambda a: regexp_tokenize(a[1],(token_regex if a[0] else string_regex)), quote_split))
    token_camel_case_split = chain.from_iterable(map(case_splitter, token_initial))
    return token_camel_case_split


def commit_msg_tokenizer(msg):
    line = basic_filter(msg)
    line = label_filter(line)
    if (line is None):
        return None
    if line.count("`")%2 == 1:
        return None
    
    backtick_regex = r"`[^`]+`|[^`]+"
    line_divided_by_backtick = re.findall(backtick_regex,line)
    tokens = chain.from_iterable(map(lambda text: regexp_tokenize(text,(token_regex if text[0] == '`' else string_regex)),line_divided_by_backtick))
    commit_tokens = list(chain.from_iterable(map(case_splitter, tokens)))
    if (len(commit_tokens) < 3 or len(commit_tokens) > 30):
        return None
    if ("version" in commit_tokens):
        return None
    return commit_tokens

def file_filter(modified_files):
    count_diff_lines = 0
    for mf in modified_files:
        if (not mf.filename.endswith(".py")):
            return False
        count_diff_lines += mf.added_lines + mf.deleted_lines
    if (count_diff_lines > 50):
        return False
    return True

def parse_repo_commits(repo_name, commit_limit=50):
    data = []
    commit_count = 0
    commit_count_traversed = 0
    for commit in Repository(
        f"https://github.com/{repo_name}",
        only_modifications_with_file_types=[".py"],
        only_no_merge=True,
        order='reverse'
    ).traverse_commits():
        commit_count_traversed += 1
        if (commit_count >= commit_limit): break
        
        # Check if changed files are python
        if (not file_filter(commit.modified_files)):
            continue
        
        commit_tokens = commit_msg_tokenizer(commit.msg)
        if (commit_tokens is None):
            continue
        
        # Create diff tokens
        diff_tokens = []
        for f in commit.modified_files:
          diff_tokens.append (['<file>'])
          diff_tokens.append(diff_tokenizer(f.diff))

        diff_whole_tokens = list(chain.from_iterable(diff_tokens))

        data.append([repo_name, commit.hash, json.dumps(commit_tokens), json.dumps(diff_whole_tokens)])
        commit_count += 1
      
    
    print(f"[DEBUG] {repo_name}: {len(data)} / {commit_count_traversed}")
    return pd.DataFrame(data, columns=["repo", "hash", "commit_messsage", "diff"])

# %%
import time
start = time.time()
#df = parse_repo_commits("soimort/you-get")
df = parse_repo_commits("getsentry/relay")
end = time.time()
print(end - start)
df.head(10)

# %% [markdown]
# # 3. Create whole dataset via Multiprocessing

# %%
data = []

def f(repo):
    start = time.time()
    df = parse_repo_commits(repo)
    #df.to_pickle(f"./repos/{repo.replace('/', '+')}.pkl")
    end = time.time()
    print(f"{repo} took {end-start} seconds")
    return df

pool = multiprocessing.Pool()

obj_len = len(repodf['repo']) // 100

for i in range (100):
    if (i == 99):
        outputs = pool.map(f, repodf['repo'][obj_len*i:])
    else:
        outputs = pool.map(f, repodf['repo'][obj_len*i:obj_len*(i+1)])
    pd.concat(outputs).to_pickle(f"repos/data{i}.pkl")
# Out:
# 9f7082badf855db344226a830e9442616fadef7c: commit_tokens failed
# d6dd67e388b58247dd4a03c29bf6e625d6e4e230: files failed
# cba727ca4cb344350f92d93ad01f6a3b183c11c6: files failed
# 20ecaeadf2144b88555a3daf1a04e31b7f2ff95a: commit_tokens failed
# aff1e1bcaea3b6152e3cc0593d4925db4ce09eb1: commit_tokens failed
# 849217a7731cbcfcf64432ccf306f4e4001328f2: files failed
# 3c3442e17d4d01ba7cde2679025cec3bc7263306: commit_tokens failed
# 48b7c3a9bdfdf507672cd2f8d175e738da2f62c5: files failed
# 17d535efba03070cbc505d915673e0f24d9ca60c: files failed
# 14f437a04b70e71bbb038fc2d3916d64be362c79: files failed
# 21d880ffadc0462e5afce467b962d73fda858c7d: files failed
# 4c5b4d1972d6ae09d228952fdd0ff2d717d851a3: files failed
# 631513fe42cb0b0613349f17118faabf879107ac: files failed
# d90de4ae8547e6725a1ec7bf4914be55d1fe32de: files failed
# 98e6fe7c118922ccca1f5df1ab83d90967b7d2e4: files failed
# fe1f639c099ca853587801d00c873622eded215b: files failed
# 9b9eb7a776fe94abf787d24b705cdc00f6d9fc0d: files failed
# c0fbfd9555987bfe6a7f19f7817848737e76362b: commit_tokens failed
# 2ffa621c44f8ee2e26d871406ef91f558beabfa0: files failed
# a361c525ac98596d3b40011ccba84beb407d8c25: files failed
# c89cf80b256c444cdb88e9e2a11ee09e368a4be9: files failed
# b2c0837c2a7c09a325f8355962e5552d3102f204: commit_tokens failed
# 9a0f7400957c5b5f5f8e952db2502ef1f79fac1f: files failed
# b3e1766207ce76035c07528f031338978404db4f: files failed
# 3332f45e4361209fb1665bcd86bc261cfc08e452: commit_tokens failed
# a5d050f099e8f0255985648ecd5c1ca20d14c61f: commit_tokens failed
# 959458784ea25811a4941db0dedbaf7c3038dfc3: files failed
# d7823f3d7883e84f6f9e1aec419a023cf5edc632: commit_tokens failed
# 427a6242d1df5a72c37ffb4f449da8eb9ede59a8: commit_tokens failed
# 6fdf7ba78012bebe4fd358a3c068d73496058f46: files failed
# db3e9f4c3baad3e62c113d4a9ddd2e3983d324f2: files failed
# a7552997515d1dee975d63a341aa98595cfe26cb: files failed
# 89505a7aa40a02f30d647221eeab39dac41df41b: files failed
# 8368fdebdd816c4387bef22de9d31f43bb1e3e63: files failed
# b97bbfbd27317b2fa89126898f386459316bb359: commit_tokens failed
# e8280404d5bf9ac714d8523ca71a370b8dec1065: files failed
# 084f153f20145ea3ec729c9c8ce48a85147870e5: commit_tokens failed
# ccd00af0b315e401c9918840010514f8659e62e0: files failed
# 938f482d99a03f6978043c9ff878f5f63f3f9967: commit_tokens failed
# 76613a7420e26d5e5373d323bbb01b42feb723c0: commit_tokens failed
# 8989a0a0f8af610111dee79379b00ed914ec8af8: files failed
# dc7e2bbefeee336cd043355bc253fe92314aed29: files failedf9e25cd8fe07d322f78382a72cfdd5bacb429b83: commit_tokens failed
#
# b9bd42d0141f268d955c64f56db41fcc8bd65fce: commit_tokens failedd974797e12856414e978db5346d027df5433a608: files failed
#
# 31409352e1585f2b4c372476e013ce3a00c93582: files failed
# eb625bb41ad24f806467fcc799357d6063d861fa: files failed
# 487db716ee86bb9dbb96b65af9516f45be06bcbc: files failed
# 626e6ddeffbbe50f1042a2a80e49c7fee73b8cd1: commit_tokens failed
# d27f4c8290650e04c4797eafb3af0dc9811a7b37: commit_tokens failed
# 10b80933474d91c06aee5cc94b920cb900bc145c: commit_tokens failed
# bf288132f8bbd6f3a7b2f53fbf88b52304a5c43b: files failed
# 673349632c904895bfa0aeb4ad40b762b45f9ea7: files failed
# 60db6af37c1cd75711cb00199ba1363fac85cee7: files failed
# 0d5f4343eb8483c6b56b26e4f408a9c08d70226b: files failed
# 2538518b1dc158f4f6832b63b8bfc1f9f8440ec8: commit_tokens failed071e184a7c550cd6f9362a2ad278f5a5d5776927: commit_tokens failed
#
# 98ae3a363360e9d7bb0c9a252442b068a734029a: files failed
# 4065329b1898dc98bc9e1d1df0487cbc8bf01e75: files failed
# 6af146350d850e7b4c84b9d9292f511cb01bbd70: commit_tokens failedc0d0a4d2d9cb99e0b64f138ac4bccd61c465389b: files failed
#
# 2db8fef88e959398a7a30c28031c1037d73d4886: commit_tokens failed
# ccd2728529ed446768f825c0ff266c36cf450635: commit_tokens failed
# b93345cd727a18b07af3f6e1785400e61dda60ac: files failed
# 334547d7cdd50f50a45de5cae6869a47e32c838a: files failed
# 3696d1ce5034f0ac6a7ba4da9e064b09a365392c: commit_tokens failed
# a769721aeabc2408476ad9d47d4c97174b96698f: files failed
# 5753ea19d7d83413cf64ecce6360a2f29ef920bf: commit_tokens failed
# 3106c6e6deeea134522f057b2bedb59ff0cc1137: files failed
# da0ca61f747e8a777205bb648d824bf4c330c91f: files failed
# 300ad765e2ac38f02f96910e8d31db487b5862e4: files failed
# 174ed5f49655360add738184a2b86398cdaeb660: files failed
# d1ea435d2fb8daef2d37042aa9165f9a456ea499: commit_tokens failed
# 864e01ddf9ebeb00e44324e57c94dcfa53e95aba: files failed
# 26b229df54ea484e7a4f1b7f8c2ca777d6c7d91b: files failed
# eea07058fb2d9d49ad2f9b31353ad210e7e5abc3: commit_tokens failed
# 50bf713bd971c27d1855d7581d29874235ddb059: files failed
# 94faf441a9426206f6e71d1db7952c1458c11f94: commit_tokens failed
# a50e106ebd341d0340c7056d6ccf0f7a524cddf1: files failed
# 96fd08bbaefc7a0afb73727eca997db586e6e2b5: files failed
# 6757546e405de6505754f22751492cc984c5c3a8: files failed
# d4b2a5804efc257857910ac1238b6452fce0e01e: files failed
# fb52d9b263ac8cce08a9f13cc6040c4c6e469817: files failed
# cc21241751d4aa913886f0f9462358eac95897ef: commit_tokens failed
# 82dc5fd0716d256866e73948dcab88128b24337f: commit_tokens failed8eb1cc3da01a43996cddafc2c19b9546eca40a33: commit_tokens failed
# 7d710d8543d9afeff6f96013d6ca50afe9084195: files failed
#
# d9aa57ba52732ab21f007b9c8f6d92d67bcb417b: commit_tokens failed
# 8872577271d8c50e8e0a1a4cf9e2589f9e54c09f: commit_tokens failed
# 8499b21ad2565e88aff23fb973d61ee74f113fde: files failed
# 5481e69f89d16e45fdd4b7f02c8bf07b38ef8d8c: files failed
# 3499f11797e286282676656c5b709d4ea36b50b6: files failed
# 798ad6d14eb23ee0754ead224494911fcf27cd68: commit_tokens failed
# fc26932521e299ab0574ac3203da9e74b7f44d4b: commit_tokens failed
# 33bd25b72ad1e7285d44bc96a93d482a4615415f: files failed
# df9af40a5ff71a500d73dc0d4ffa036745962d25: commit_tokens failed
# e69ee68eaeb9c3cc758f979a45d742290487df48: files failed
# c126de7a6611e9eb6f3734578b576649fe159510: files failed81167515142f50cbe0e3b2fb3fae1133b5ab2d7f: files failed
#
# 63fd9716a8740fc6862b70a474e398ca6e9f26bd: commit_tokens failed
# 2aa5fbd7d06761e43cbf4081a2c8ce16a18ba393: commit_tokens failed5498c377ff3e8c03831ecef9defe18bea8b4937d: commit_tokens failed
#
# 9fafb0a573070f32d0f4cb75532f884c46315e6b: commit_tokens failed
# 6c641be78316d4db8d02728840dad0a9fdad82de: files failed
# 36ac0d106f1997c77f67693073356cd9ba573c78: files failed
# d4d4a027d5dee7c09f180dd16668ed1f1603559c: files failed
# ad24e68baa5106522c6d4a37395896e9776ea88f: commit_tokens failed
# 86a2478788440c567fa86f4f16e67f37c62066e4: commit_tokens failed
# 8d0b14557ce5279797e65f2a66ff5fef07f19039: commit_tokens failed
# 9dd9fdf80b657592bbc70341c59b246850f1efe8: files failed
# 01875b83cb678ede74ceead7e455a62ca089006e: files failed
# 69c61b11760e1650b071b8273349f07df482edee: files faileddb0e3dbe0235956d6ab4f63b3e3054aebaea4bf1: files failed
#
# 79508f91da707d5d0feeddc62142b438b2a6e9a6: files failed
# e38dc11643d07d1eeafcf34418f2298735e79863: commit_tokens failed
# 931dc2e7509b1fcd6ce804681086fb327fd36441: files failed
# 0e118e57ad6005c8a4a8a193223c44c6a8bae16e: files failed
# 435ad5fb4fae06748c3a687b5052b1450143be66: commit_tokens failed
# d40a15de5c15babe7daa4eb939e5c2f50a90f68c: commit_tokens failed
# 091042516d441b4b4942dfc7defcc0a2cd910c95: files failed
# edb358d0b878ba12824b4a39dd5f28cab41a051f: commit_tokens failed
# 98531205efafcad4f41bd862d3d70b8ab8cda6ea: files failed
# ff072a24675ee693b47f4f97f85da564935f024d: files failed
# 797d508a339536694f29c3717598af21c77c207b: files failed
# 3e28f9f7128cbb544c94f1b6e20e9a0f82aee23c: files failedf9fbe8fae02a6ada9f64e0dcfbb960c856701ad6: commit_tokens failed
#
# 519059b253490e97456747e299fb366b0aaae4d2: commit_tokens failed
# 7a3b53353c113b0df442eaa7cb6b5e3459a54764: files failed
# bf622d78c4f889f9f0f7abd64b34fdd30fe4261b: files failed
# 5104dd3058c342998b32dabdd47230c5f3af75c6: commit_tokens failed
# 893f2b0c3ec83f4a11ed9270dbb0cc017c78ade6: commit_tokens failed
# 008c5f4e7c0c2ac66562681c9d72052754af7059: commit_tokens failed
# aad12bbc1d585ef17e3b30bfbee5969da7c642a8: commit_tokens failed
# 6abcdd180dc3ddb12ca926a74bfe51499caaebac: files failed
# 9c78d4122c7d396f014435feed4058953f6612c0: files failed
# e264376bd1e7f707454b0898c532569f72415561: files failed
# 2ff23667af25d9f2f92bae346a1c6ac6a04a8e38: files failed
# ce5741f31e8077f9db5abc1c9e065ebae3d1cc7f: files failed
# 17eff492fe1db0c378f2447b54c5f09ed98b2626: commit_tokens failed
# a64a75dd74fbfcb06956fe0752bcd86e740d2ff0: files failed
# 73114fb7bb1c2819085cf5c30359383cafb76169: files failed
# 8274ebec58f04fb96347fc4fa568f1913c25ae38: commit_tokens failed4b7b2b2978b7b249f3f5ea2e0d58ebe5b3f0baca: commit_tokens failed
#
# bb45d6eba7c5d71caa96567962f1c015d326b2e2: files failed
# b6b9a96c361950c73106c14b3cf3678865f6b0e0: commit_tokens failed
# 179918ae02e4d7168b8beb18235d3f196513e63f: files failed
# a3dde1319b93c87e2ee3373506436439f8834c4f: files failede5f14aee0b9000de38d3e2706b9c67de9283afb8: files failed
#
# 955edb663b8729c637078092e0970573533df288: files failed
# d812c9b9ad455fc35f853d1b4824995046ddd2a1: files failed
# 92ac149d544a39821528c6882dc63ae08be5147e: commit_tokens failed
# f31b26a9afa9cb4e0d6f27f9535edc29e4134439: files failede20b68de201b44151b3d7aaf28f34121297fa45a: commit_tokens failed
#
# 8b473e725662bfff520d27c2eb1589d46fcafda5: files failed
# a01e82e8c408bde32cbd7acf21786da755ac700f: commit_tokens failed
# aee6d118fe172a938fe5b99454f9d689a8a3f1a0: files failed
# a830eb31ad5f53adbd8b96121a9772e6b7555edc: files failed
# 484d03ab6f52c05455adb06541e9d8d0189d6967: files failed
# af402d091c4442f28e90c0a646206756396abbd0: files failed
# a3354fa85af3da0a1e130db34bdff1b374e0de05: commit_tokens failed
# 4ca675ed45850c4391aced82f2ae61f0f5194105: files failed15cc69a120cd297f2a12c5000eb1d9717e3105f4: files failed
#
# 8a15fb9aca8234ed396c9f66e9a3d9919f25efec: files failed
# 576fedad370bf2bf6864b14e44dfe40d2177579e: commit_tokens failed
# 22f59375a70d47e467c902eaeb6f979660995b84: files failed
# 18c751e87ac319eb7acf988ba262fbb76789d2e9: commit_tokens failed
# dd8240b5308a65579131bc354ceb9f225851052d: commit_tokens failed
# 5c0f63c68811f969c0944d1164cbe710211564f6: files faileda2155e85f89b6315b3e3145e97c95b93b087951a: commit_tokens failed
#
# db140c0213d5c9e4d40635f8645128ad63d24ceb: files failed
# ab12816988846616e2a45e06de4605e209fbfc17: commit_tokens failed
# 4f8c73e9ac27198e15694affb20a615fa9ffa48c: files failed
# a334f14de9a016a830d2a56bd7c920bebd90d44b: commit_tokens failed
# 18d184be938cbedff79b3ded77d52f66fda8545c: files failedea98709f1cacb25666941434ec658be6db9695e8: files failed512026d2dadc79ce1c71e921af8885b15cf993c3: files failed
#
# 3c36813b7a3de2d2ee926c4564aec932490477f1: files failed
#
# 89cb749b498a22b7936c5d9ee6c245131733daa6: files failed
# 0d6762d4d1ce269faeb0e9717a312bc4b72976c6: files failed
# 24bd74df307b097baf87f28637943d264f155a09: files failed
# 08a00727255bb924da04b99b853281d9efda7bcc: commit_tokens failed64df6334b4c0c753b8f6cefe3735792f06dacf96: commit_tokens failed
# dca0760caa6fb0e5662c3e5b0b21931b9ed62584: files failed
#
# 5a890eac531546f7bc737a0616a86262e418acdf: commit_tokens failed
# 7e75fefb44b41b45e8995141b0f1f39e7a39caf6: files failed
# 7e2984e0a14ae2566de253bc79e7da38a68b3f30: files failedfe998dde62e5ffb2dd4557fa2771a8f04babfef2: files failed
#
# a77bc6b099e63b7deb71ad037869790246126e29: files failed
# 17c740ae542e4ce2285da8775152cde8cbc782b8: commit_tokens failed37d374f08c6d5c327cdb4dea2b06bab02f13f87e: files failed
#
# d826311246a2465b5da2dac4a237e0d39dd10e81: files failed908e326ba9e5feb01cfbe6e21fc7d14665366a59: commit_tokens failed
#
# d214cbf50d39f85426c74fb6a3721a5195b3493c: files failed
# 3010f0148bad83da8323c0b84f9f43df93786187: commit_tokens failed
# e726fc4ca4cea56d0fb54a8c43eecc07563391e1: files failed
# b73cc4f145ad3f3a4ce930ca5ffbcd278cc1998b: files failed893c8e415091212daad2a69ecaf419230f332363: files failed
#
# 95aeb4fdfa4b1a09c0da60328e1312ab3221e7d1: files failed
# 5c2bb3fa3448efeaf014009bd1a1daa43680683e: files failed
# 6a7345b3b26320d8821923504186938a5735ed96: commit_tokens failed
# b00860e4beed7d72a20f212c5ab9f443b779dc2d: commit_tokens failed
# e8b78b72259ce39fdeb88afba7c2fbf99edfb69f: files failed
# ac7b670bcae1a60bc8b2c7f0ebd1a54eb807559e: commit_tokens failed
# 2a0f969d474a2ea4e7248f52cca83e87fce62b44: files failed9283a06f87cc9bb80832c1d6f94773eed186e6f5: files faileda61c448d73dd95c3118f44a288bb6ae27903f953: files failed
#
#
# c8d5ca447652bcc57eff657d81292c60f06c076a: commit_tokens failed
# 514eaae8671ab77bc7b5e2f252ad67c9bd327206: files failed
# 2a9a2af127012cca052369348bb8bceccc885ecd: files failed
# 6e39a594e4b09b1379be649517dcf2d237ef6263: commit_tokens failed
# 6f9cd8a069611e69d26da77eac676d33ca99c735: commit_tokens failed
# 37e5135708101fffadc6574b88a871d414f4088a: files failed
# 1ada1c29b6f2e302e293c679cc90abe36021e774: files failed
# 3a137586490ab1a29f21edd5bbdecca6de464100: files failed
# c9001c70e9c0e43b105b6fbf4996c128f1bda5c1: commit_tokens faileddca5024ae1fb6345836f8f87aca9c2afa8d32455: files failed
# 7b420db7bd2d49a5acde64280ddfa9cfe101b56d: files failed
#
# d95a02a3edf2836493f0af575658146a324b7d75: files failed
# 6325d63268da6863950a1b5e83bf6caaee3a98f2: files failed
# d1b45ed27d572bf84c94b54b56b68a14067bf227: files failed
# c074d8100110c1c2eed27f2f4ffb12f7670d6e74: commit_tokens failed
# 46baa9e3a4563888b8b463460600051834eb6331: files failed
# 999b677e30089faf311cf2ae28d9ed09f1df5100: files failed887148d7dbb5ff9bbc08955ecb70e579488ddc97: files failed
#
# 966fc9c9edf7db6766f97058e33c759b2d40b408: commit_tokens failed
# 4f599121d2f89b6613084ff8fdaa2986955b69de: files failed
# 180ec7881a1129210427149d2b2974ad30ebd97a: files failed
# f751231aac5b560821b28cf6d62016fc2c3f2a11: commit_tokens failed
# 265b059163bf3eff7d7505e906632bf3cab37549: files failed
# a5d3bd5e34ba5261dcea2188a4addd62b80c0ed7: commit_tokens failedd3f329de6e0a8dd2a201231f92dbae47c9c8e89c: files failed
#
# 5808ae58511dbbe5cdeed9cb40b9970088390a7d: commit_tokens failed
# 619b42d5068e5f20f6f654b79c96f6f97d9009ba: files failed
# 0cd2ccf9498fe4aea4867b8adb8be169e70ccc5e: files failed4e60926bc82408f14392a1c52918e85f16f3b3ba: files failed
#
# eb3240541682f308ae0e8a80f99eaf21c76a77bc: files failed
# cc4f211382287b28b6434dafdc69a3607eb3d9d8: commit_tokens failed
# cda4a1e6f18dd4633a316a6e8c6f110ccbe21698: files failed
# 04d68a0b64b0ad2706b605e80f06b103c2bab5b0: files failed2c39f17990ea39ac18ff54b4f902ec9acccae3ce: files failed
#
# 7a776802e39f8e3c1a4a176977f4bf1c017217b5: files failed54dbd82826971d99a18f9b3ed076510b95c25d03: files failed
#
# 260b80063b7d3599f93d7179a7749d626f010973: commit_tokens failed
# 5d59f76a41bca9a88495d2b721dc5618a1a568ba: commit_tokens failed
# 2b6e7f3d476d7005a012c88266ef94d9051e60f9: files failed
# a93f93cc791702d1e8f55cc1ad84b955d76aee2a: files failed
# 97d74eee20c1cb87ce2192d792b1462b06ce54fa: files failed
# 7e5b21c550d6fd03170df3858f3b253daa4f8ac9: commit_tokens failed
# ea92e34d7626daf62904f7d3d81cad11cef8ac6d: files failed
# 102d2aade7cdcb6034f232ce5906789d9666b970: files failed9eca332356cd7385c49ae64093455837d3e32dc1: files failed
#
# 5c9ec6c4f300dda24fcf0ad6b75a45e3cec46536: files failed
# acb79f1510bd67acc0e726d4371ded2a8b87197a: files failed184bbcefb97219d8a07797e417afddb0d8a48531: commit_tokens failed
#
# 4a60eb7a52aa3ce3a77e2453e11dda9d5f9130e5: files failed
# d17c2848a3dfcfc5985a5a2ffddbd88d7b07da0d: commit_tokens failed
# 60e2a34b2719031ec1bbcfeb173b7ae4e3d45c34: files failed
# da1d772cd84326b2258c3b8b889324105317573f: commit_tokens failed
# 1391436dbba635efb56615739d91fdbb2f23cd9c: files failed
# [DEBUG] graphql-python/graphene-sqlalchemy: 50 / 101
# cd90e3563ee42fb267a66bc748609b7e1e42f4e4: files failed
# graphql-python/graphene-sqlalchemy took 6.794357061386108 seconds
# 0ff358704fae1331ecbacf95740426e65d58337b: files failed
# c935e9dd56faea7262f4a4305e7f7635996e5ec9: commit_tokens failed
# bfac0f626e9528045c2ba54e78f2cc7afaa90e80: commit_tokens failed
# 07f1e9c42d77361c8f794ac5b5fc918e071a29cb: commit_tokens failed
# 1fd086c54a4c99ea248705153d4a28a289cf6654: files failedb3e4129987890a2beb04f2c0b6dc618ae35f2e14: commit_tokens failed
#
# [DEBUG] soimort/you-get: 50 / 80
# soimort/you-get took 6.956393480300903 seconds
# ec97e4502d05a6f15ae56140103ce63b0e2e2b89: files failed
# 9afe792b1adbfa682c87a931ec637119c8010cb0: files failed
# 573f3fca77f6b3c2a200b106af75cae2f6be30da: files failed
# d080c5554f3efa65012cd31c090dbb9caf8ebd4d: commit_tokens failed
# d6042dc72f1a49e9d991457c6c55c9ef88913df6: commit_tokens failed
# 1b57da0e95b4f30201b27b99f3776752eb8f1573: files failed
# cfc91b937122c9ea84eb26e80bc62ff1a0955fb2: files failed
# 2902cb4a15816074da1374553faeb35b77cbc63a: files failed
# 1c3dc7570de8c68e61e4e22ff869f649f7ea5a91: commit_tokens failed
# f3d1643635360146367c8ca58d46580cbcf01d55: files faileda1e297f8d4729ff07ba747c0af8d538a1c5d5ced: files failed
#
# 7337c80be71f1b77c5861bd78bbc459c33d828ce: files failed
# 98acd131cb1a148a62109d5d725009634f266a89: files failed
# 6aaecd4cf60c43801d566b8e2858f34a926929fd: files failed
# 653085086434ef118e13168e0d4d6269e606555e: files failed
# 610139b95a7de9cf16105c1fba6e38e07eb5ec7b: files failed
# c2654a7ee5a2398bf566ab6114413be7d4caf96f: files failedfc61ca97ac6d06d3aad6a79d39b1672c03634508: files failed
#
# c62720ff771ee5a5073b3e8a3309c8d252976fc8: files failed
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-9:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15851/3502582536.py in <module>
#      21         outputs = pool.map(f, repodf['repo'][obj_len*i:])
#      22     else:
# ---> 23         outputs = pool.map(f, repodf['repo'][obj_len*i:obj_len*(i+1)])
#      24     pd.concat(outputs).to_pickle(f"repos/data{i}.pkl")
#
# /usr/lib/python3.9/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# /usr/lib/python3.9/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# /usr/lib/python3.9/multiprocessing/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# /usr/lib/python3.9/threading.py in wait(self, timeout)
#     572             signaled = self._flag
#     573             if not signaled:
# --> 574                 signaled = self._cond.wait(timeout)
#     575             return signaled
#     576
#
# /usr/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-5:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-12:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_15851/3502582536.py", line 9, in f
#     df = parse_repo_commits(repo)
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_15851/3502582536.py", line 9, in f
#     df = parse_repo_commits(repo)
#   File "/tmp/ipykernel_15851/3502582536.py", line 9, in f
#     df = parse_repo_commits(repo)
#   File "/tmp/ipykernel_15851/3502582536.py", line 9, in f
#     df = parse_repo_commits(repo)
#   File "/tmp/ipykernel_15851/3502582536.py", line 9, in f
#     df = parse_repo_commits(repo)
#   File "/tmp/ipykernel_15851/3502582536.py", line 9, in f
#     df = parse_repo_commits(repo)
#   File "/tmp/ipykernel_15851/3502582536.py", line 9, in f
#     df = parse_repo_commits(repo)
#   File "/usr/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_15851/2998431124.py", line 104, in parse_repo_commits
#     for commit in Repository(
#   File "/tmp/ipykernel_15851/3502582536.py", line 9, in f
#     df = parse_repo_commits(repo)
#   File "/tmp/ipykernel_15851/3502582536.py", line 9, in f
#     df = parse_repo_commits(repo)
#   File "/tmp/ipykernel_15851/3502582536.py", line 9, in f
#     df = parse_repo_commits(repo)
#   File "/tmp/ipykernel_15851/3502582536.py", line 9, in f
#     df = parse_repo_commits(repo)
#   File "/tmp/ipykernel_15851/2998431124.py", line 104, in parse_repo_commits
#     for commit in Repository(
#   File "/tmp/ipykernel_15851/2998431124.py", line 104, in parse_repo_commits
#     for commit in Repository(
#   File "/tmp/ipykernel_15851/2998431124.py", line 104, in parse_repo_commits
#     for commit in Repository(
#   File "/tmp/ipykernel_15851/2998431124.py", line 104, in parse_repo_commits
#     for commit in Repository(
#   File "/tmp/ipykernel_15851/2998431124.py", line 104, in parse_repo_commits
#     for commit in Repository(
#   File "/tmp/ipykernel_15851/2998431124.py", line 104, in parse_repo_commits
#     for commit in Repository(
#   File "/tmp/ipykernel_15851/3502582536.py", line 9, in f
#     df = parse_repo_commits(repo)
#   File "/tmp/ipykernel_15851/2998431124.py", line 104, in parse_repo_commits
#     for commit in Repository(
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 233, in traverse_commits
#     for commit in job.result():
#   File "/tmp/ipykernel_15851/2998431124.py", line 104, in parse_repo_commits
#     for commit in Repository(
#   File "/tmp/ipykernel_15851/2998431124.py", line 104, in parse_repo_commits
#     for commit in Repository(
#   File "/tmp/ipykernel_15851/2998431124.py", line 104, in parse_repo_commits
#     for commit in Repository(
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 233, in traverse_commits
#     for commit in job.result():
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 207, in traverse_commits
#     with self._prep_repo(path_repo=path_repo) as git:
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 233, in traverse_commits
#     for commit in job.result():
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 207, in traverse_commits
#     with self._prep_repo(path_repo=path_repo) as git:
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 207, in traverse_commits
#     with self._prep_repo(path_repo=path_repo) as git:
#   File "/tmp/ipykernel_15851/2998431124.py", line 104, in parse_repo_commits
#     for commit in Repository(
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 207, in traverse_commits
#     with self._prep_repo(path_repo=path_repo) as git:
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 233, in traverse_commits
#     for commit in job.result():
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 240, in _iter_commits
#     if self._conf.is_commit_filtered(commit):
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 207, in traverse_commits
#     with self._prep_repo(path_repo=path_repo) as git:
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 207, in traverse_commits
#     with self._prep_repo(path_repo=path_repo) as git:
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 207, in traverse_commits
#     with self._prep_repo(path_repo=path_repo) as git:
#   File "/usr/lib/python3.9/contextlib.py", line 117, in __enter__
#     return next(self.gen)
#   File "/usr/lib/python3.9/contextlib.py", line 117, in __enter__
#     return next(self.gen)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 240, in _iter_commits
#     if self._conf.is_commit_filtered(commit):
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 240, in _iter_commits
#     if self._conf.is_commit_filtered(commit):
#   File "/usr/lib/python3.9/contextlib.py", line 117, in __enter__
#     return next(self.gen)
#   File "/usr/lib/python3.9/contextlib.py", line 117, in __enter__
#     return next(self.gen)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 233, in traverse_commits
#     for commit in job.result():
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 240, in _iter_commits
#     if self._conf.is_commit_filtered(commit):
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/utils/conf.py", line 267, in is_commit_filtered
#     if not self._has_modification_with_file_type(commit):
#   File "/usr/lib/python3.9/contextlib.py", line 117, in __enter__
#     return next(self.gen)
#   File "/usr/lib/python3.9/contextlib.py", line 117, in __enter__
#     return next(self.gen)
#   File "/usr/lib/python3.9/contextlib.py", line 117, in __enter__
#     return next(self.gen)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 170, in _prep_repo
#     local_path_repo = self._clone_remote_repo(self._clone_folder(), path_repo)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 170, in _prep_repo
#     local_path_repo = self._clone_remote_repo(self._clone_folder(), path_repo)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/utils/conf.py", line 267, in is_commit_filtered
#     if not self._has_modification_with_file_type(commit):
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/utils/conf.py", line 267, in is_commit_filtered
#     if not self._has_modification_with_file_type(commit):
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 170, in _prep_repo
#     local_path_repo = self._clone_remote_repo(self._clone_folder(), path_repo)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 170, in _prep_repo
#     local_path_repo = self._clone_remote_repo(self._clone_folder(), path_repo)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/utils/conf.py", line 267, in is_commit_filtered
#     if not self._has_modification_with_file_type(commit):
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/utils/conf.py", line 282, in _has_modification_with_file_type
#     for mod in commit.modified_files:
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 240, in _iter_commits
#     if self._conf.is_commit_filtered(commit):
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 170, in _prep_repo
#     local_path_repo = self._clone_remote_repo(self._clone_folder(), path_repo)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 170, in _prep_repo
#     local_path_repo = self._clone_remote_repo(self._clone_folder(), path_repo)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 170, in _prep_repo
#     local_path_repo = self._clone_remote_repo(self._clone_folder(), path_repo)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 151, in _clone_remote_repo
#     Repo.clone_from(url=repo, to_path=repo_folder)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 151, in _clone_remote_repo
#     Repo.clone_from(url=repo, to_path=repo_folder)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/utils/conf.py", line 282, in _has_modification_with_file_type
#     for mod in commit.modified_files:
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/utils/conf.py", line 282, in _has_modification_with_file_type
#     for mod in commit.modified_files:
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 151, in _clone_remote_repo
#     Repo.clone_from(url=repo, to_path=repo_folder)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 151, in _clone_remote_repo
#     Repo.clone_from(url=repo, to_path=repo_folder)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/utils/conf.py", line 267, in is_commit_filtered
#     if not self._has_modification_with_file_type(commit):
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/utils/conf.py", line 282, in _has_modification_with_file_type
#     for mod in commit.modified_files:
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/domain/commit.py", line 668, in modified_files
#     self._modifications = self._get_modifications()
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 151, in _clone_remote_repo
#     Repo.clone_from(url=repo, to_path=repo_folder)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 151, in _clone_remote_repo
#     Repo.clone_from(url=repo, to_path=repo_folder)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/repository.py", line 151, in _clone_remote_repo
#     Repo.clone_from(url=repo, to_path=repo_folder)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1148, in clone_from
#     return cls._clone(git, url, to_path, GitCmdObjectDB, progress, multi_options, **kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1148, in clone_from
#     return cls._clone(git, url, to_path, GitCmdObjectDB, progress, multi_options, **kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/domain/commit.py", line 668, in modified_files
#     self._modifications = self._get_modifications()
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/domain/commit.py", line 668, in modified_files
#     self._modifications = self._get_modifications()
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1148, in clone_from
#     return cls._clone(git, url, to_path, GitCmdObjectDB, progress, multi_options, **kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1148, in clone_from
#     return cls._clone(git, url, to_path, GitCmdObjectDB, progress, multi_options, **kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/domain/commit.py", line 668, in modified_files
#     self._modifications = self._get_modifications()
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/utils/conf.py", line 282, in _has_modification_with_file_type
#     for mod in commit.modified_files:
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/domain/commit.py", line 683, in _get_modifications
#     diff_index = self._c_object.parents[0].diff(
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1148, in clone_from
#     return cls._clone(git, url, to_path, GitCmdObjectDB, progress, multi_options, **kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1148, in clone_from
#     return cls._clone(git, url, to_path, GitCmdObjectDB, progress, multi_options, **kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1081, in _clone
#     (stdout, stderr) = proc.communicate()
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1148, in clone_from
#     return cls._clone(git, url, to_path, GitCmdObjectDB, progress, multi_options, **kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1081, in _clone
#     (stdout, stderr) = proc.communicate()
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/domain/commit.py", line 683, in _get_modifications
#     diff_index = self._c_object.parents[0].diff(
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/domain/commit.py", line 683, in _get_modifications
#     diff_index = self._c_object.parents[0].diff(
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1081, in _clone
#     (stdout, stderr) = proc.communicate()
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1081, in _clone
#     (stdout, stderr) = proc.communicate()
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/domain/commit.py", line 668, in modified_files
#     self._modifications = self._get_modifications()
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/domain/commit.py", line 683, in _get_modifications
#     diff_index = self._c_object.parents[0].diff(
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/diff.py", line 175, in diff
#     index = diff_method(self.repo, proc)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1081, in _clone
#     (stdout, stderr) = proc.communicate()
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1081, in _clone
#     (stdout, stderr) = proc.communicate()
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 1081, in _clone
#     (stdout, stderr) = proc.communicate()
#   File "/usr/lib/python3.9/subprocess.py", line 1134, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/usr/lib/python3.9/subprocess.py", line 1134, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/diff.py", line 170, in diff
#     proc = diff_cmd(*self._process_diff_args(args), **kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/diff.py", line 170, in diff
#     proc = diff_cmd(*self._process_diff_args(args), **kwargs)
#   File "/usr/lib/python3.9/subprocess.py", line 1134, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/usr/lib/python3.9/subprocess.py", line 1134, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/diff.py", line 170, in diff
#     proc = diff_cmd(*self._process_diff_args(args), **kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/pydriller/domain/commit.py", line 683, in _get_modifications
#     diff_index = self._c_object.parents[0].diff(
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/diff.py", line 487, in _index_from_patch_format
#     index.append(Diff(repo,
#   File "/usr/lib/python3.9/subprocess.py", line 1134, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/usr/lib/python3.9/subprocess.py", line 1134, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/usr/lib/python3.9/subprocess.py", line 1134, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/usr/lib/python3.9/subprocess.py", line 1979, in _communicate
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.9/subprocess.py", line 1979, in _communicate
#     ready = selector.select(timeout)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/cmd.py", line 638, in <lambda>
#     return lambda *args, **kwargs: self._call_process(name, *args, **kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/cmd.py", line 638, in <lambda>
#     return lambda *args, **kwargs: self._call_process(name, *args, **kwargs)
#   File "/usr/lib/python3.9/subprocess.py", line 1979, in _communicate
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.9/subprocess.py", line 1979, in _communicate
#     ready = selector.select(timeout)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/cmd.py", line 638, in <lambda>
#     return lambda *args, **kwargs: self._call_process(name, *args, **kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/diff.py", line 170, in diff
#     proc = diff_cmd(*self._process_diff_args(args), **kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/diff.py", line 309, in __init__
#     for submodule in repo.submodules:
#   File "/usr/lib/python3.9/subprocess.py", line 1979, in _communicate
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.9/subprocess.py", line 1979, in _communicate
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.9/subprocess.py", line 1979, in _communicate
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.9/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/usr/lib/python3.9/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/cmd.py", line 1183, in _call_process
#     return self.execute(call, **exec_kwargs)
#   File "/usr/lib/python3.9/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/cmd.py", line 1183, in _call_process
#     return self.execute(call, **exec_kwargs)
#   File "/usr/lib/python3.9/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/cmd.py", line 1183, in _call_process
#     return self.execute(call, **exec_kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/cmd.py", line 638, in <lambda>
#     return lambda *args, **kwargs: self._call_process(name, *args, **kwargs)
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/repo/base.py", line 368, in submodules
#     return Submodule.list_items(self)
#   File "/usr/lib/python3.9/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/usr/lib/python3.9/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt
#   File "/usr/lib/python3.9/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/cmd.py", line 872, in execute
#     proc = Popen(command,
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/cmd.py", line 872, in execute
#     proc = Popen(command,
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/cmd.py", line 872, in execute
#     proc = Popen(command,
# KeyboardInterrupt
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/util.py", line 1103, in list_items
#     out_list.extend(cls.iter_items(repo, *args, **kwargs))
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/cmd.py", line 1183, in _call_process
#     return self.execute(call, **exec_kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.9/subprocess.py", line 951, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/objects/submodule/base.py", line 1239, in iter_items
#     for sms in parser.sections():
#   File "/usr/lib/python3.9/subprocess.py", line 951, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/cmd.py", line 872, in execute
#     proc = Popen(command,
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/config.py", line 106, in assure_data_present
#     self.read()
#   File "/usr/lib/python3.9/subprocess.py", line 1777, in _execute_child
#     part = os.read(errpipe_read, 50000)
#   File "/usr/lib/python3.9/subprocess.py", line 951, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/minus21/.local/lib/python3.9/site-packages/git/config.py", line 564, in read
#     seen = set(files_to_read)
# KeyboardInterrupt
#   File "/usr/lib/python3.9/subprocess.py", line 1754, in _execute_child
#     self.pid = _posixsubprocess.fork_exec(
# KeyboardInterrupt
#   File "/usr/lib/python3.9/subprocess.py", line 951, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.9/subprocess.py", line 1777, in _execute_child
#     part = os.read(errpipe_read, 50000)
# KeyboardInterrupt
#   File "/usr/lib/python3.9/subprocess.py", line 1754, in _execute_child
#     self.pid = _posixsubprocess.fork_exec(
# KeyboardInterrupt
# KeyboardInterrupt
# 263b52a3d91265afc0f3d709c95ce3e0ae0b3a35: commit_tokens failed
# 07e137937ff3172b373ab18a0343273ea7942a4c: commit_tokens failed
# 97548adf6959610f3150f8fed843af1f9b74c36b: files failed
# 5727646acf1aeb41cb3102dff94637697147c772: commit_tokens failed
# 8e441f331be7ce07b4a5a6312c4514d2616035d7: files failed
# 32c0073aaf5e07ebbe6d9b2307b00e58a1248bcf: files failed
# 9505918772afa54cfdc4789a2ce04c98630bfa4d: files failed
# db700139e69e5de9f828dfd918e6b7d8b5cec43b: commit_tokens failed
# c6ae0caf42a4f4f3ffd2205fd85150d80ecb52c0: commit_tokens failed
# 0af9d65abbe866955e3df739482a2b9f41b2bcdd: files failed
# ff3d42381529b31c626abbd9b58c7e51fb7f33ff: files failed
# b491aa2bff2f363204e4c99a8e50e6d0d81a470d: commit_tokens failed
# ed5af076ff48163709f6ff83ac62e571c67ea74e: files failed
# 704a4825976ad47d89194cec18d7faa50ebde077: commit_tokens failed
# 94156a0c975f3321a061604958f5bb6ca3fdd91c: commit_tokens failed
# c8c4e84c339e76ce825a3a63b0a28ac32a09b7e3: files failed
# df215c45800928fb8642b273604066748e5de724: commit_tokens failed
# 1720cf32e0e3cb81d8382db82da8cee7992f108f: commit_tokens failed
# 5ddcc4e463783d4f321a974980920860d88e825d: commit_tokens failed
# 8962a38f35d48e655ffcd43163a63cf66f9338f5: commit_tokens failed
# 30fbe8c4440116018f06e7ef6d046e574d3155a7: commit_tokens failed
# d81fc28a3962ba5c53ddd4170a5777c07074a6d5: commit_tokens failed
# 732318167966da7f6f7ba69aef3cb096c214912f: commit_tokens failed
# adabe35ed17019ce9ee9d310680f6566780a454e: files failed
# 34cd3c6e9b8cace6ccd5267fe33db71e04480002: commit_tokens failed
# 3e57fccd31a64b94a73ff434a2277413bf215175: files failed
# de7cdd67bcfa78e8a0bebe7e0a03d6ea5da2c785: commit_tokens failed
# f533071c24f861d69abfd602e12015e0f13073b3: files failed
# a27704fa1620acfba06ca9b5c0bd1d9b62206326: commit_tokens failed
# ee83f2e7a0afc69843cb9d1d25535d0a9d109414: commit_tokens failed
# 14fa3651e35afaa968b3776e36d630f4230809ed: commit_tokens failed
# fa496818de7337b4cbd69f35bed36f13deb5cdd4: commit_tokens failed
# 5e3f3e7258a3f5e1a39fb6c82355b8f14e3256ef: files failed
# 27571f813e9dc727799417369cb5eee7af59a025: files failed
# ee275ed5418e68af510c0ce652c698257c1ff68f: commit_tokens failed
# 3d4ce061de239f37e34f80bd691bd8940ddc5020: commit_tokens failed
# 27b2f45039ab2c67db1146ce220ef263c8709b00: files failed
# 3fba70a22eb5521c12d81302ff978a92c8113909: commit_tokens failed
# 5368968c7f377e7ec7069ec77bced7270d453311: files failed
# b834e67098b1887ab1986174a7a0e1c1088684fd: files failed
# 636401ca1167fd56d0d933cac49b082e7035d06b: files failed
# 775654c36f68e56e03bfd9f28c93342ff1a0f191: files failed
# aedc565de2cb7bd44b4fe80594caf417f850fcb6: files failed
# 736ba69f8a5db7b1f8115af05b8fa17d14ba5bab: commit_tokens failed
# d10bcab3345d1cbe13f07732c07d758f64767c4f: commit_tokens failed
# 1c2dd286007d32a701bf0c439dd3b2ebac354df0: files failed
# a687a2f680ea587b0bf633af09b55c76519e3593: commit_tokens failed
# ...
# e6e4df895f96d6d4710c2d4adc6f88f798bf14a6: commit_tokens failed
# 6961846f7070b6c07886fdee576d0bda879574f2: files failed
# 047084f7bd8ff5eb4a62b151a6523de648f85a85: files failed
# 64630f09a0e1039b93d089d5becf30f6fc33a5a7: files failed
# e84e7b57d1838de70ab7a27089fbee78ce0d2106: files failed
# 52792d460b39bfa70bb83f54587cdb10072d1906: files failed
# 8572040fbe18a80a34adc901b8fee1f7f1ea12f7: files failed
# d8e929927ca9e9e09b4ecaa7fb5f104063a10480: files failed
# 7f6af68b89e35a3e7bac3d4ea5619c9555819de0: commit_tokens failed
# 7d0c04ceb8e6e4d721f6b69fe0e14b08784e645d: commit_tokens failed
# 60a0eef29878433e568a16b16a8c6e42b59cabe3: files failed
# 82254c2a78ce31d8540c0a01d919385c21e17a01: commit_tokens failed
# a42ec20880d44150022b8cd9c852fff6cca2dcaa: files failed
# f976b6adf25211410dc5339ed186d5822f6d3bc7: files failed
# 0f6253c2be513e8358a81f09621006ccce578807: commit_tokens failed
# 1dd209d9313ef7d98f0a0adfb4028b2a7df2d256: files failed
# 7c619dffbc33446d0ce02964753a8abebc984658: files failed
# 51717970261d6283b681f5fa8347808409f0991d: files failed
# 42b85c9f7a6d8149e4638feb2dc5ab60ba61e2e9: commit_tokens failed
# c46233bfec1e09ba11c5f0866c8766dc5ee3a022: files failed
# cec4c9f484eb717455072c7b2517cc153bc410d6: commit_tokens failedf4cca783b88184def8cac1f9dbde898f9c639776: files failed
# c6795b95042958b3b66067cf1a857542cda2835d: commit_tokens failed
#
# fe63ad0573f5040c33febb52f05f90e02a56b8a6: files failed
# d203529c4aeba13f6898a855bd48a6a081bfd761: commit_tokens failed
# 7456143933066fd5db1951a093cd438cf9803fde: files failed
# a0e3275295e41a1e7169087e18ff41a28dd4504f: files failed
# ff34ef4b95e84b78e0940aa56bc8ce1bdabac335: commit_tokens failed
# 976b07a73803644f9a62e0de4a1dc832840703a3: commit_tokens failed
# 2be0c8677e77dca03829e1a588a627e1ee037111: files failed
# be4e99373215874d466446b72f19c1e52c05f4e7: files failed
# 5dc698861c91b4aa83b284b282c0e91cdcee49a3: files failed
# d290855aab9f12d7cf739c63aad9ca3699d936f7: files failed
# b0ecfa879af67f3e75ecd0c6d84c5aa8f7404a39: files failed
# 35687196d71949e275cbef9be63a546065b0d6f4: files failed
# 614d6737d84294b038eead384100e2a7a65f717b: files failed
# a261ee69e6d5b6aa2a29403e8a4d9e843ff0915f: files failed
# e418f2ce406e797474d4821dd3be1659a8d48f0a: files failed
# 2f26202d0e8acc24e22bede20b1456d63c3ed107: files failed
# 956d41801c257919ca657ea5dfc13934c967e739: files failed81a57554aeb1b48171ac1d36d801206a16ff1cb0: commit_tokens failed
#
# 4211b909fb5aa2c4db2b0f5acbab1480972a0554: files failed
# cdbfd828fcbfdd21c61bde6ceb9db6a6329605f0: files faileda809399aaac482b7127126122aa28c19eee8bfdb: commit_tokens failed
# b9a3d15adfa852d27eb1e3257578f02ddba75308: files failed
#
# ac6868147999f98878e2237596f01bc771e80556: files failed761aec80f028ca414b5bd7f35ea7ac195d446440: files failed
#
# 5412226bfbac7435db32adbec71b7bdbe6db573c: files failed
# 1eb6766d9b4eff07aa6165af4d12d64e8f49e0f2: files failed
# 1955e04cbd8b1272b9d20b473fbddbc89033d676: commit_tokens failed
# d29022ba1273db990ae94c3e30d47674a27ce62e: files failed
# de2dbf7c56b18ddc69d797b64859d57949dbf310: files failed
# ea109c0d4fc492bcbd6f0ae56fb73cc1d8f42ab0: files failed
# 6c075f4c39ff87da152c63f71c8651027414faf9: files failed
# [DEBUG] Terrance/SkPy: 50 / 66
# Terrance/SkPy took 4.85540246963501 seconds
# 3562df8732f66848342874526d0ce12392d7d62e: files failed
# f3667e95188e8c14458a7943c7efab3776b04711: files failed
# 364a97067524a0e4a35dfab2d6e0c25efa27edec: files failed
# 8cb366fbec2b7e85c6747e2233a64752708b61cf: files failed
# 124a0134fdb7decb0136b4b6f7892b87b919e74e: files failed
# 669dcc3488a4803b2c321218def6554805940c48: commit_tokens failed
# ad240659df800bb033d1dc37e65c04de487156e4: files failed
# cdd6696025b997646497b85cc0db6b27db12f92b: files failed
# 888753789159c2f88de7e7cc984489616d5b9cf9: files failed
# 83ef2306a1481e0cf7f53899c390497256711e29: files failed
# 86355c7bcfbf5ebd55e1f0c786d2ae4c2c078fbf: files failed
# 43c97767afe7aa1dccefec35946dbc8b9cde73a4: files failed
# 4222224bc4d051797b32e10566daf784853ed848: commit_tokens failed
# ca0c68fee052e667d7fd944253cfa9c8542bf2d4: files failed
# f0e035c8ed39e821e2a155e3d62151d31f643a91: commit_tokens failed
# 79b9c79148f51fc9321ab4450947b259cb5804fb: files failed8bd36dcf23a5e8bdcc5f7c0e8470e310cd0db054: files failed
#
# 33c5499ce34f5e1c7c2630c6a1446353eee31755: files failed
# bb971ae935059b73830ea2abe3f66391125b2bfb: files failed
# 3701a08c81c51d1adaa480176f913fa4497053da: commit_tokens failed
# 6866e7d585bca78839e881737c5d4827710cc825: commit_tokens failed
# 41dc136a28c9c66bafd1e5abd94e09fe2db1229f: files failed
# df59f3a4989bacb70e8748b4ad56f51b14c8f011: files failed
# d8ae9c9750274ffc76b1d7d3694fba65a923623d: files failed
# 9a80576f9fa841d0045f90e495055f8c61d49496: files failed
# 39ae442caf4e04da4309fe5a9b694acc639e6b95: files failed
# 4073917d3e269d6fb7175fbbd18e61fb835010f8: files failed
# 688538cc0e84b1cb168de78be509cd63bf397763: files failed
# 8483edfbe21ffbacf5d2230e970ce0ffe7924d39: files failed
# 2b724b87c3a18f9edda64b1ea5b79a1eef80bfd1: files failed4e6c6ef5e884577e2d6533473274dc4f86382fd1: files failed
# 6e4d15b10a0b72c6ef58c43f3efc18165ab8b194: files failed
#
# beaf9f514ae9db428a17e96520111c27f3c330d9: files failed
# 17b56ae07bff4080c27524872046cf377f8f9ccb: files failed
# d5e7e2e912a86a6605188e57fc49d7a8c7e70d38: commit_tokens failed25b8c2136ecce7c7ead6329b6d32c728b92f2868: files failed
#
# c45a6ea2c9a792d1cf55eed024bad519d3174819: files failed
# e4f384c2b76615b68f32f6d6df24017b0a383fcf: files failed
# 4575222cf9ba7647dad923999dcc2319aac2c92b: files failed
# bb7acd2b2a7e27c51a4e815e79e8be7b8ccdfc2c: files failed
# 54aa437278fc392792928cbc5563954667e6b701: files failedb2bca41bdee8ed315d9f97ef89bdc234defd3b4c: files failed
# 761aaccb3f7a7551733174d5dfeecb7e6ca2f834: files failed
#
# 5036df387ab64c967353f626c65edd79fac38edf: commit_tokens failed
# 2257e32153b0189d713723d823494b0a80988509: files failed
# 6630ead8beb696863a17ae64cf498c6b5ea6e7d8: commit_tokens failed
# 037371861693f26297320dcd5fd8c221b6d8df26: files failed
# 956dda88d9c27971cfea100c23ccbe75782138e1: files failed
# 2dca7a75eef7c931abbbb6b9a87b1659db5ae6c8: files failed
# 2d04397913b8340948be9a8a6544cc3283a35d1b: files failed
# d7e1f4116239a3202ae0e8566144c69525e1f448: files failed
# 4ee62e52681018156625f2346d20ba4fcba939cd: files failed
# 45de34906244cd7963f5b75f1ff0ed7f47a3ffad: files failed653d427166c499f422d2ffcd6f267b600e8f84fc: files failed
#
# a8d63aba1c3a9713bf6cd56338307f34e6dec2a3: commit_tokens failed77debda56711fd5bd454596378943126852b1818: files failed
#
# 98c57be751fe18fec6d05152965f53ed9ade0872: commit_tokens failed
# 128221ddaa3dd6959dfb7e47ae5cb9a5a8a6f8bd: files failed
# 9ffb77d2d4a275368776cb19ed4136dc6ce49e4d: files failed
# e30c951c7fc0c7b1477b8521f1e751d93dd2ea6b: commit_tokens failed
# 56e33208ae221d6970e717f15d6a3326b84f557f: files failed
# 76ac6f24ef2ccd165ad6f8e346db650cfcbdd502: commit_tokens failed
# 04377f32e00aaaf798f1642aac4d132696a1b7f3: files failedadaa2dcad54fa3bfdcf679f6cc793675c9ed807d: files failed1ede58449a42f23b140022db2e6ec656c44b2780: files failed
#
#
# 8c861ee308092368690a1d9e23a67b0197d2346b: commit_tokens failed
# f806cc01d37a9e2ffd9821d3317caf82dce401ad: files failed
# daf6f0060959c896fd724da5ade401ec70a8d1e5: files failed
# 565ca928f46301eceb9d87df0436db48728f9be0: files failed
# da402f4a545256c5dfe78448c75dcf47fcd0b4d3: files failed
# 5d890a00af541abe379c2eea76ab668080eabff6: files failed
# 079c963ddd4ebfd13a905829bc341dce85d94fbd: files failed
# 08800e487ff16612a9f87b97feed84e3c4de9bfb: files failed
# e12aff5c0d2dd7647313788aaa77ba3053b81a64: files failed
# 8543286168ed3bb234395d66fb401714495ff198: files failed
# 309bcc87a168424fd2145e4e972b1a4f927bf336: files failed
# 3dc77a823139501f569f6925ee87ec3f5e6572ae: files failed
# 3ddf0366e60e925b78662608c9bfa1e42b6452b3: commit_tokens failedfc802df5c10f0d1cd9749c94887d652fa26db6fb: files failed
#
# f1896f6001c8451c40f7edddb658dd7246d8cf1b: files failed629767590be0e7ed2fb13e414cb24c4c5d0774d5: files failed
#
# 0209467c39afd726b07c4f3fef3da65ebf0796e1: files failed
# a18137385f574603535b29ad935f496d307ab3ae: files failed
# 8c98377218900bd85896428b662c63710bf50cee: files failed
# feb0f88ddc0aa577d0d377e2b8e48a0be88feb4f: files failed
# a7b4929eabfa9b9fdd0e1aee7c3d3738f6e5c9f0: files failed
# f0455d2cd029ee12f338a1ed088d849e63d299f9: files failed
# 684023d0b64cd2519b9b34d7ec4410a04e54d413: files failed
# dc44dac7eff9b119cceff511a79eb81ea9b0a918: files failed
# 1c7535448eceda9d1a288696c7ead181cee06fa7: files failed
# 140a69e9347d3c664698405baf3531e0eebbe7e6: files failed
# 239920655fff67df3bec1abfd4a941fd47115bfa: files failed
# 9f328eb74a270c0d30d6234e098e2fb3e36958d7: files failed
# [DEBUG] WoLpH/mt940: 50 / 112
# WoLpH/mt940 took 10.685693979263306 secondsaeca8a4364799492229c2ee6e1d12086a46fa7ce: files failed
#
# 0427ace079b2c691904cca2ae4425f7777623ae1: files failed1fbe064c50fd030948141d7d630673761525b0d0: files failed
#
# 5630520771de46c9a777284f29d0cae5849b0c5e: files failed
# 837ba3b6f7645dd7bc6fc92980af12d549c8790a: files failed
# be2bd54f4bf0c8ea50eaf5fd7343652f2bdf9eca: files failed
# 789871899c4617ecb6a82ae82d571ec5abc698db: files failed
# b6278a8991c8729c22c35cc0960fa0ff1dc72518: files failed
# a0ce89054a02651c86fe8a4559a4218a5047df5c: files failed
# e2d4aac518e5e8254c58e9f088ca44e4c2cf0030: files failed
# 01f90a1b010754c37a332b1b432bca73f7c529a2: files failed
# fc4a96ebab4a9a6a536e542407541cabcc0e7d5d: commit_tokens failed
# 5db8bf73453d069fa41b7f9c8563be3012e4651a: files failed
# c4331f6cd6d2b182b2ba9f511d0badf14d4b4cc6: files failed
# 997e18de8e7e8fbcabdd4dc2e3b3a0b1be74266b: files failed
# f0a59cd8a9f945b437fdb07ad7fc8664fe0a9cf6: files failed
# c2b472fb02b129699f8583dac0a80f424a9505f1: files failed
# c9a71e155f08a4d9af36c97b22df9f4215e6c995: files failed
# fd70632df34aded187b64c820070e3ba65cf7650: files failed
# b6537678a70961ecabfc618273a46f5bc1dabd15: files failed
# fee3f696c46a062c1ca717773372e777bc797d0e: files failed
# dc6c35a0b6dc5a96e15d8863933125dba61bf1d2: files failed
# d714528c5a8ec8e4286176c5711398100bc2c23c: files failed
# e3aa5032f04268e036b5d632f4c6d8ba5eb21fa2: files failed
#
# 7d5a3bfd55c7c9de71af877e773dce4554cf455b: files failed6f25ced08ea538b55e1a942c4bed48dae5d30de7: commit_tokens failed
# a01e67364630c10da635b9d43eaa535f05feff63: files failed
# 0e6c553bc57587dc644430b7336e6bf4d90180a6: files failed
# 178d04da82bab78bf36a85b2a728dbfaa44fb3de: files failed
# 50cef2646b18171ec6b50e4abde75438813815b5: commit_tokens failed
# 0f82c1f04f6710e2f182582068f186c4fffc3f9b: files failed
# d5e561a08f7a322d8f9fcd240ca5c42237bb1da2: files failed
# 12aa003799ee3240f8c523e9133101dcd37778a1: files failed
# f1f0ac668f4596deda356fbf62157b8092a2e11a: files failed
# a65949823d9303055ff31dfe6cd4083c146721d7: commit_tokens failed
# a40e8612b75fe2d82058d33e2d4aaa5e782c2344: files failed
# 74de8a137d435d45c100b74cc971be556166a559: files failed
# aa4f9fb96751bcd2d210e347376ad71498afb6da: commit_tokens failed
# 8fac96d19b6e993afaada35b2d51bf016bcf224f: files failed
# 460a19d45425218c34dcb7d6fde478f80a987fea: files failed
# bb17bb82ac7e75cb0106b061a28409772c1500a1: files failed
# 52989273237dffc14394a57d12c936c546d4f183: files failed
# a137ef0e02fa97dd11a1e28a25a0318cc9a4dc1b: files failed
# 02261ad7a51f8cad31c548a67f8406a1ef5ff052: files failed412128f7f970e593427f50efc1f900eb6b0a6d24: files failed
#
# 8ba400800b7f5b663e000919219f506b30ca8cc0: commit_tokens failed4bdf8e4e3abe6e726084e2a7e21afb62d7fa9027: commit_tokens failed
# 3b24ec2ea061390a89d63baafda5d987dd5e4467: files failed
#
# f7ba363b93598c98ce46230994c4fcfb619a559d: commit_tokens failed772be756ff2336b2bc1c3d31e69e16dc6fb7434c: commit_tokens failed
#
# 40bc0f17b2a4e6c215f0c70968e89928f260e685: files failed
# d6f722ad3a726ac63bb07ec25c6191523fe2f718: files failed
# 15c293505749cb8d2e65a1034e4ff03d26db3cf5: files failed
# 7472ad68e8b8db3a4340405093b7fd9ecf4105f3: files failed
# b31bcd61fc918fe5b5bc3c0e1cff78fa6947ab3a: files failed
# f9e9e70771598f4316e6b64b6d6016925f50c3e4: commit_tokens failed
# 346d89ad943c4f76de5fb0665f01b08aee3ec031: files failed
# [DEBUG] ndokter/dsmr_parser: 50 / 95f4e6f3b7882a63611deddd6dc27dd036089f5ba3: files failed
#
# ndokter/dsmr_parser took 7.903354167938232 seconds
# ac41a2229d14140cf028a5f974907352862e30c3: files failed
# 72e71999f34274ceca8da70fb8db6d6cc55c7a95: files failed
# 1ae7cb68cd285fe822c84d8e3198aff9716cf4e8: files failed
# 471a0f57bca06cd1b71882ae2734ac442045c631: files failed
# d072cae3a4e0d41602ffd0730a838fa12657ed4a: files failed
# 3d231f03ed24f760d1896f5e2be3adf1cbf13127: files failed0165ffbd2ba0d718ab86d572c06f1c748e650bb1: files failed
#
# 02cb1fe607a9aa9fa8c2fc1aee24d48186cb5de1: files failed
# d21fcd810317aa7579af0c194a61af377ade7f0e: files failed
# 70181c3182db221a24bcbddab82d866246c216bd: files failed
# 738d22bf5310ae54bb453a0889da98cc88104ebb: files failed
# 6eac81ec7976d7d66debeacea5147d4dcf035974: files failed
# bdb7639ad53427fae38695d2dc5bf5bd794787c8: files failed
# e73818600065821d588af475b024f4eb518c3509: files failed
# 736c62111550972d835e33a3084c3bfc37bb61f7: files failed
# 57051a53e154c2b401ab84d6f01c6512e6c7b346: files failed
# e84ce685b1ddf4c615da82be216e984cc64b61c3: files failed
# 5a3fb407b3d7b2f2dcc144055ee707614ead1817: files failed
# 8984fa87ff51adf6095ce1013d023902f3449375: files failed
# acbd662b62a2de0e7102d560f7e73d7feaf9e600: files failed
# ea16ae6b6a49a922c6092bfeda0e1c2a4b08a939: files failed
# 4aa52c33d3ee51c632e0e1e10cafb7745fd1028c: files failed
# 54dc58be3ed440287538572235fa74916e0726b7: files failed
# c3697ad289dc011692591246e8d6d341f37da298: files failed
# f49ae9a1008f7059d50992002c1e7b9c5ed71d0b: files failed
# fe0120f9fbf08ca937cc95cf409c0d888145fafa: files failed
# 1eac0e8f9b3829c5401151fabb3f78453ad772a4: files failed
# fb7fda0a82588a033f5d998b3fd1be33f3fb8148: files failed
# 1f1ee2a6279dfe075d3d841ded0c5c7fbd7f9ee3: files failed
# 9bd33dc016debc662f044204d5e2d186a9673837: files failed
# 6d86887144e7d209468cbcfbbe05d40e69ed10cb: files failed
# 4b6293b4b06a0a31f3fef6edb6d1667b046bc732: files failed
# 993924859671f861405d90eaaae1dfe8b6965c28: files failed
# 48b7abd79c9566bb141b3d20f6cd2a80ce83066a: files failed
# 23c965e7864bd9f37cf2c6076895c9bec395f00c: files failed
# 209de940c3d36e700d73385b417cb94064c13919: files failed
# 6cbc69abfa93746d3c4562031d626d6b0943450f: files failed
# a079213940ce64709476c46d062c8caefbca1b09: files failed
# 229afc7e41e64587efb1eeb2925ea83a0975a155: files failed
# a723ba2d4800a8bb682926dcf7eee900e6e8c6bf: files failed
# dd4466249bd5129fa3166324f46bd004b834567a: files failed
# 3c531c92d07eed85a4ed8ff5ae42215624315767: files failed
# 87c421051681b9e22760835571c523f873e47ade: commit_tokens failed
# 59d26251efd8a2a08abd9029018194430f7f25ca: files failed
# 231c908da6b9507e1b29cf8a6bea2b9c40f1b65d: commit_tokens failed
# 8102128e6ad83dcbb3567dd372cdd39c9a8fab44: files failed
# 059a5ba4901f66eb21ca94248d1a172b5a9bce3a: commit_tokens faileda5ae79508e06bd76442dbea62f5dbafa88332cd7: commit_tokens failed
#
# a92a1a708f3973d0640a6f7c9e43adf1e6925f82: files failed2f29a6f0a87b201ac0b983094826b06145c333e1: files failed
#
# [DEBUG] pyca/pyopenssl: 50 / 144
# pyca/pyopenssl took 17.233829021453857 seconds
# 4334ef279528f8161352832427e87027c0316d57: files failed
# 0c13de94befcbec4eb4adfb3014cfd491baa1aeb: files failed
# cd711a8e34af2494dae6c215f9f844940b91cd01: files failed
# 23793730c03292a3462ea501b4ac22872ec46d22: files failed
# 86da423e65623dadc7453d8f4ba7b5d7b1011b90: files failed
# 58237dc1f7a1296630951179b78a29a77c730b85: files failed7f4149cc57d650d7fc3f9a3617824b62d43b71a8: files failed
#
# 8e96d9293fcd67e479f36c421d1dfa35d597f4a3: files failed
# d70371ff756481b2663c2148445b642341827851: files failed
# [DEBUG] hustlzp/Flask-Boost: 50 / 113
# hustlzp/Flask-Boost took 19.991029977798462 seconds
# 17b9f71e5157c79a56b7718d55dd6a998de7581f: files failed76a6547715fb3f6de2f0600995d400bac707ff7d: files failed
#
# 16263795354c117d6aafde5dde56deaa02584d3f: files failed
# 8449a7c3576bbd21163df19500aca989dda05700: files failed
# d69737af86dee538d676a04458018cf5dfa8b9df: commit_tokens failed
# 6a6c37066c31979fedef0bb0227acd38a7b0934a: files failed
# bf35709341bf94f71b52fbd27ab8447e686c9199: commit_tokens failed
# 7d6f27139bc38b0bddb4e378cf3fe34260a8e143: files failed
# 941e3b39ba2677d94e692ddfa5fa64651a08f1e2: files failed
# b528ee55cc516bb851a2be87a11b1b3c32c6edca: files failed
# 636869e736d5a6fa6bcdd195985f3989dd100b26: files failed
# e97131882a3f922c8a454c83f3a77e502df3e563: commit_tokens failed

# %%
df = pd.read_pickle(f"{root}/data.pkl")
df.head(3)
# Out:
#               repo  ...                                               diff
# 0  soimort/you-get  ...  ["<file>", "\n", "output", "filename", "= ", "...
# 1  soimort/you-get  ...  ["<file>", "\n", "cookies", "= ", "none", "\n"...
# 2  soimort/you-get  ...  ["<file>", "\n", "def", "zhihu", "download", "...
#
# [3 rows x 4 columns]
